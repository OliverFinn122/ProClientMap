# %%
# %run classes.ipynb
# %run functions.ipynb

import os.path
from opencage.geocoder import OpenCageGeocode
import folium
from folium import Tooltip
import pickle 
from typing import List
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual, IntSlider, Output
from IPython.display import clear_output, display
from datetime import datetime
import pytz
from typing import List
from copy import deepcopy


#old_clients = load_old_clients('data.pickle')
#full_client_list = update_clients(old_clients)

full_client_list = load_clients_pickle('client_data.pickle')

days_of_week = {0: 'Sunday', 1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday'}

out = Output()
out2 = Output()
out3 = Output()

time_slider = widgets.IntSlider(min=6, max=23, step=1)
print("time slider military time 6 - 23")
display(time_slider, out2)
time_slider.observe(hourly, names='value')

slider = widgets.IntSlider(min=0, max=6, step=1)
print("day slider")
display(slider, out)
slider.observe(weekly, names = 'value')

# Create separate sliders for day and time
day_slider = widgets.IntSlider(min=0, max=6, step=1, description='Day:')
time_slider_2 = widgets.IntSlider(min=6, max=23, step=1, description='Time:')

# Combine the two sliders into a single widget
day_and_time_slider = widgets.VBox([day_slider, time_slider_2])

# Set the observer for each slider
day_slider.observe(filter_by_day_and_time, names='value')
time_slider_2.observe(filter_by_day_and_time, names='value')

# Display the new widget
display(day_and_time_slider, out3)

sunday_map = filter_and_save(full_client_list, "Sunday")
monday_map = filter_and_save(full_client_list, "Monday")
tuesday_map = filter_and_save(full_client_list, "Tuesday")
wednesday_map = filter_and_save(full_client_list, "Wednesday")
thursday_map = filter_and_save(full_client_list, "Thursday")
friday_map = filter_and_save(full_client_list, "Friday")
saturday_map = filter_and_save(full_client_list, "Saturday")
        
time_client_list = modify_time(full_client_list)

#for client in time_client_list:
    #print(client)
    
#test change

while True: 
    inp = input("Enter add, delete, search, print, map, day, time, day-time or e to exit: ")
    if inp.lower() == 'add':
        add_client()
        remove_append()
    elif inp.lower() == 'delete':
        remove()
    elif inp.lower() == 'search':
        search()
    elif inp.lower() == 'print':
        for client in full_client_list:
            print(client)
    elif inp.lower() == 'map':
        map_nyc = create_map(full_client_list)
        display(map_nyc)
    elif inp.lower() == 'day':
        pass
        break
    elif inp.lower() == 'time':
        pass
        break
    elif inp.lower() == "day-time":
        pass
        break
    elif inp.lower() == 'e':
        break
    else:
        print("Invalid input")
        
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# time slider military time 6 - 23
# IntSlider(value=6, max=23, min=6)
# Output()
# day slider
# IntSlider(value=0, max=6)
# Output()
# VBox(children=(IntSlider(value=0, description='Day:', max=6), IntSlider(value=6, description='Time:', max=23, …
# Output()
# Enter add, delete, search, print, map, day, time, day-time or e to exit: map
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82056ef87055af4413431025b1336fe0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82056ef87055af4413431025b1336fe0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82056ef87055af4413431025b1336fe0 = L.map(
#                 &quot;map_82056ef87055af4413431025b1336fe0&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92d5e28263e04759a4321bcabc7245e4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_82056ef87055af4413431025b1336fe0);
#
#
#             var marker_061b1c57b3505c284521ff7e33d63121 = L.marker(
#                 [40.7198779, -74.010019],
#                 {}
#             ).addTo(map_82056ef87055af4413431025b1336fe0);
#
#
#         var popup_9a8a3b774a290b74496e91b23d38d5dd = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_50a8c490208b8b86078d763cc42e2637 = $(`&lt;div id=&quot;html_50a8c490208b8b86078d763cc42e2637&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Name:&lt;/strong&gt; Luann&lt;br&gt;&lt;strong&gt;Time:&lt;/strong&gt; [&#x27;Monday 6/5 10:05am&#x27;]&lt;br&gt;&lt;strong&gt;Length:&lt;/strong&gt; 20 minutes&lt;br&gt;&lt;strong&gt;Address:&lt;/strong&gt; 377 Greenwich St, New York, NY 10013&lt;/div&gt;`)[0];
#                 popup_9a8a3b774a290b74496e91b23d38d5dd.setContent(html_50a8c490208b8b86078d763cc42e2637);
#
#
#
#         marker_061b1c57b3505c284521ff7e33d63121.bindPopup(popup_9a8a3b774a290b74496e91b23d38d5dd)
#         ;
#
#
#
#
#             marker_061b1c57b3505c284521ff7e33d63121.bindTooltip(
#                 `&lt;div&gt;
#                      Luann
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fc19dfe96392d47121e19d817a89ac38 = L.marker(
#                 [40.7202082, -74.0099615],
#                 {}
#             ).addTo(map_82056ef87055af4413431025b1336fe0);
#
#
#             var icon_1d66778aa01ce31be7211b9b786c9923 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fc19dfe96392d47121e19d817a89ac38.setIcon(icon_1d66778aa01ce31be7211b9b786c9923);
#
#
#         var popup_71876f866711bb894a84812cc1b8689f = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_c25f065e69fe875c44ce1734cde6ea3c = $(`&lt;div id=&quot;html_c25f065e69fe875c44ce1734cde6ea3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Name:&lt;/strong&gt; Jeter&amp;Andy&lt;br&gt;&lt;strong&gt;Time:&lt;/strong&gt; [&#x27;Monday 6/5 8:30pm&#x27;]&lt;br&gt;&lt;strong&gt;Length:&lt;/strong&gt; 30 minutes&lt;br&gt;&lt;strong&gt;Address:&lt;/strong&gt; 385 Greenwich St, New York, NY 10013&lt;/div&gt;`)[0];
#                 popup_71876f866711bb894a84812cc1b8689f.setContent(html_c25f065e69fe875c44ce1734cde6ea3c);
#
#
#
#         marker_fc19dfe96392d47121e19d817a89ac38.bindPopup(popup_71876f866711bb894a84812cc1b8689f)
#         ;
#
#
#
#
#             marker_fc19dfe96392d47121e19d817a89ac38.bindTooltip(
#                 `&lt;div&gt;
#                      Jeter&amp;Andy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a913de00de08ee8485cda65dc0748b9a = L.marker(
#                 [40.7088046, -74.0174483],
#                 {}
#             ).addTo(map_82056ef87055af4413431025b1336fe0);
#
#
#         var popup_5b64b94eef1cad4b6981539be2138f39 = L.popup({&quot;maxWidth&quot;: 250});
#
#
#
#                 var html_d69a26f7db4b71629250ae9f1e6a322d = $(`&lt;div id=&quot;html_d69a26f7db4b71629250ae9f1e6a322d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Name:&lt;/strong&gt; Baby&lt;br&gt;&lt;strong&gt;Time:&lt;/strong&gt; [&#x27;Sunday 6/5 9:15pm&#x27;]&lt;br&gt;&lt;strong&gt;Length:&lt;/strong&gt; 30 minutes&lt;br&gt;&lt;strong&gt;Address:&lt;/strong&gt; 300 Rector Pl, New York, NY 10280&lt;/div&gt;`)[0];
#                 popup_5b64b94eef1cad4b6981539be2138f39.setContent(html_d69a26f7db4b71629250ae9f1e6a322d);
#
#
#
#         marker_a913de00de08ee8485cda65dc0748b9a.bindPopup(popup_5b64b94eef1cad4b6981539be2138f39)
#         ;
#
#
#
#
#             marker_a913de00de08ee8485cda65dc0748b9a.bindTooltip(
#                 `&lt;div&gt;
#                      Baby
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9fcf86afae91ba087ef58595aa750e60 = L.marker(
# Enter add, delete, search, print, map, day, time, day-time or e to exit: e
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
